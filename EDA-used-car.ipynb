# %%
import pandas as pd

# define dataset path
# dataset source https://www.kaggle.com/datasets/mohitkumar282/used-car-dataset
path = r"dataset\used_car_dataset.csv"
car_data = pd.read_csv(path)

#cek 5 data teratas
car_data.head(5)
# Out:
#            Brand      model  Year  Age     kmDriven Transmission   Owner  \
# 0          Honda       City  2001   23    98,000 km       Manual  second
# 1         Toyota     Innova  2009   15  190000.0 km       Manual  second
# 2     Volkswagen  VentoTest  2010   14    77,246 km       Manual   first
# 3  Maruti Suzuki      Swift  2017    7    83,500 km       Manual  second
# 4  Maruti Suzuki     Baleno  2019    5    45,000 km    Automatic   first
#
#   FuelType PostedDate                                       AdditionInfo  \
# 0   Petrol     Nov-24  Honda City v teck in mint condition, valid gen...
# 1   Diesel     Jul-24  Toyota Innova 2.5 G (Diesel) 7 Seater, 2009, D...
# 2   Diesel     Nov-24  Volkswagen Vento 2010-2013 Diesel Breeze, 2010...
# 3   Diesel     Nov-24     Maruti Suzuki Swift 2017 Diesel Good Condition
# 4   Petrol     Nov-24       Maruti Suzuki Baleno Alpha CVT, 2019, Petrol
#
#      AskPrice
# 0  ₹ 1,95,000
# 1  ₹ 3,75,000
# 2  ₹ 1,84,999
# 3  ₹ 5,65,000
# ...

# %%
#cek 5 data terbawah
car_data.tail(5)
# Out:
#               Brand     model  Year  Age    kmDriven Transmission   Owner  \
# 9577          Skoda   Octavia  2014   10  105,904 km    Automatic  second
# 9578  Maruti Suzuki  Alto-800  2020    4   55,000 km       Manual   first
# 9579  Maruti Suzuki      Ritz  2013   11   92,000 km       Manual   first
# 9580        Hyundai     Verna  2019    5   72,000 km    Automatic   first
# 9581        Hyundai   New i20  2021    3   83,228 km       Manual  second
#
#         FuelType PostedDate  \
# 9577      Diesel     Oct-24
# 9578  Hybrid/CNG     Nov-24
# 9579      Diesel     Nov-24
# 9580      Petrol     Oct-24
# 9581      Petrol     Nov-24
#
#                                            AdditionInfo     AskPrice
# 9577       Skoda Octavia 1.9 Elegance TDI, 2014, Diesel  ₹ 10,40,000
# 9578  Maruti Suzuki Alto 800 CNG LXI Optional, 2020,...   ₹ 3,75,000
# 9579               Maruti Suzuki Ritz VDi, 2013, Diesel   ₹ 4,15,000
# ...

# %%
#cek jumlah row dan kolom
car_data.shape
# Out:
# (9582, 11)

# %%
#cek kolom yang ada di dataset
car_data.columns
# Out:
# Index(['Brand', 'model', 'Year', 'Age', 'kmDriven', 'Transmission', 'Owner',
#        'FuelType', 'PostedDate', 'AdditionInfo', 'AskPrice'],
#       dtype='object')

# %%
#cek info detail dari tiap kolom
print(car_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9582 entries, 0 to 9581
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Brand         9582 non-null   object
#  1   model         9582 non-null   object
#  2   Year          9582 non-null   int64
#  3   Age           9582 non-null   int64
#  4   kmDriven      9535 non-null   object
#  5   Transmission  9582 non-null   object
#  6   Owner         9582 non-null   object
#  7   FuelType      9582 non-null   object
#  8   PostedDate    9582 non-null   object
#  9   AdditionInfo  9582 non-null   object
#  10  AskPrice      9582 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 823.6+ KB
# None

# %%
#check data with empty value
car_data[pd.isnull(car_data.kmDriven)]
# Out:
#               Brand              model  Year  Age kmDriven Transmission  \
# 231   Maruti Suzuki           Alto-800  2019    5      NaN       Manual
# 353          Toyota             Innova  2016    8      NaN       Manual
# 444           Honda            City ZX  2024    0      NaN    Automatic
# 476         Hyundai        Santro Xing  2010   14      NaN    Automatic
# 608          Toyota              Etios  2012   12      NaN       Manual
# 793           Skoda             Kushaq  2010   14      NaN    Automatic
# 976        Mahindra    Bolero Neo Plus  2015    9      NaN    Automatic
# 1164       Mahindra         Bolero Neo  2023    1      NaN       Manual
# 1199           Tata             Indica  2014   10      NaN       Manual
# 1413        Hyundai        Santro Xing  2007   17      NaN       Manual
# 1978           Tata          Tiago Nrg  2021    3      NaN    Automatic
# 2680  Maruti Suzuki         Zen-Estilo  2008   16      NaN    Automatic
# ...

# %%
#drop empy data from dataset
car_data.dropna(subset='kmDriven').reset_index(drop=True)
# Out:
#               Brand      model  Year  Age     kmDriven Transmission   Owner  \
# 0             Honda       City  2001   23    98,000 km       Manual  second
# 1            Toyota     Innova  2009   15  190000.0 km       Manual  second
# 2        Volkswagen  VentoTest  2010   14    77,246 km       Manual   first
# 3     Maruti Suzuki      Swift  2017    7    83,500 km       Manual  second
# 4     Maruti Suzuki     Baleno  2019    5    45,000 km    Automatic   first
# ...             ...        ...   ...  ...          ...          ...     ...
# 9530          Skoda    Octavia  2014   10   105,904 km    Automatic  second
# 9531  Maruti Suzuki   Alto-800  2020    4    55,000 km       Manual   first
# 9532  Maruti Suzuki       Ritz  2013   11    92,000 km       Manual   first
# 9533        Hyundai      Verna  2019    5    72,000 km    Automatic   first
# 9534        Hyundai    New i20  2021    3    83,228 km       Manual  second
#
#         FuelType PostedDate  \
# ...

# %%
#since i live in Indonesia, i want to know the price of car in this dataset in my own currency
#create new column by converting askprice type from object to integer, deleting currency symbol and replace floating number
car_data['price_in_lakhs'] = car_data['AskPrice'].str.replace('₹', '').str.replace(',', '').astype(int)

#convert the price to rupiah (at the moment i write the code, 1 lakh = 188.292 rupiah)
car_data['price_in_rupiah'] = car_data['price_in_lakhs']*188.292
car_data['price_in_rupiah'] = car_data['price_in_rupiah'].astype(int)
car_data.head(5)
# Out:
# c:\Users\M. Albar Ghiffar\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\dtypes\astype.py:189: RuntimeWarning: invalid value encountered in cast
#   return values.astype(dtype, copy=copy)
#            Brand      model  Year  Age     kmDriven Transmission   Owner  \
# 0          Honda       City  2001   23    98,000 km       Manual  second
# 1         Toyota     Innova  2009   15  190000.0 km       Manual  second
# 2     Volkswagen  VentoTest  2010   14    77,246 km       Manual   first
# 3  Maruti Suzuki      Swift  2017    7    83,500 km       Manual  second
# 4  Maruti Suzuki     Baleno  2019    5    45,000 km    Automatic   first
#
#   FuelType PostedDate                                       AdditionInfo  \
# 0   Petrol     Nov-24  Honda City v teck in mint condition, valid gen...
# 1   Diesel     Jul-24  Toyota Innova 2.5 G (Diesel) 7 Seater, 2009, D...
# 2   Diesel     Nov-24  Volkswagen Vento 2010-2013 Diesel Breeze, 2010...
# ...

# %%
#converting kmdriven to int
car_data['car_driven_in_km'] = car_data['kmDriven'].str.replace('km', '').str.replace(',', '').astype(float)
car_data.head(5)
# Out:
#            Brand      model  Year  Age     kmDriven Transmission   Owner  \
# 0          Honda       City  2001   23    98,000 km       Manual  second
# 1         Toyota     Innova  2009   15  190000.0 km       Manual  second
# 2     Volkswagen  VentoTest  2010   14    77,246 km       Manual   first
# 3  Maruti Suzuki      Swift  2017    7    83,500 km       Manual  second
# 4  Maruti Suzuki     Baleno  2019    5    45,000 km    Automatic   first
#
#   FuelType PostedDate                                       AdditionInfo  \
# 0   Petrol     Nov-24  Honda City v teck in mint condition, valid gen...
# 1   Diesel     Jul-24  Toyota Innova 2.5 G (Diesel) 7 Seater, 2009, D...
# 2   Diesel     Nov-24  Volkswagen Vento 2010-2013 Diesel Breeze, 2010...
# 3   Diesel     Nov-24     Maruti Suzuki Swift 2017 Diesel Good Condition
# 4   Petrol     Nov-24       Maruti Suzuki Baleno Alpha CVT, 2019, Petrol
#
#      AskPrice  price_in_lakhs  price_in_rupiah  car_driven_in_km
# ...

# %%
#describe dataset
car_data.describe()
# Out:
#               Year          Age  price_in_lakhs  price_in_rupiah  \
# count  9582.000000  9582.000000    9.582000e+03     9.582000e+03
# mean   2016.361094     7.638906    1.063609e+06     1.747726e+08
# std       4.087226     4.087226    1.658495e+06     2.791123e+08
# min    1986.000000     0.000000    1.500000e+04    -2.147484e+09
# 25%    2014.000000     5.000000    3.610000e+05     6.684366e+07
# 50%    2017.000000     7.000000    5.990000e+05     1.120337e+08
# 75%    2019.000000    10.000000    1.125000e+06     2.071210e+08
# max    2024.000000    38.000000    4.250000e+07     2.108870e+09
#
#        car_driven_in_km
# count       9535.000000
# mean       70605.891453
# std        56308.596299
# min            0.000000
# 25%        43000.000000
# 50%        65000.000000
# 75%        86000.000000
# max       980002.000000

# %%
#check unique brand column 
car_data.Brand.unique()
# Out:
# array(['Honda', 'Toyota', 'Volkswagen', 'Maruti Suzuki', 'BMW', 'Ford',
#        'Kia', 'Mercedes-Benz', 'Hyundai', 'Audi', 'Renault', 'MG',
#        'Volvo', 'Skoda', 'Tata', 'Mahindra', 'Mini', 'Land Rover', 'Jeep',
#        'Chevrolet', 'Jaguar', 'Fiat', 'Aston Martin', 'Porsche', 'Nissan',
#        'Force', 'Mitsubishi', 'Lexus', 'Isuzu', 'Datsun', 'Ambassador',
#        'Rolls-Royce', 'ICML', 'Bajaj', 'Opel', 'Ashok', 'Bentley',
#        'Ssangyong', 'Maserati'], dtype=object)

# %%
#check value count for each brand 
car_data.Brand.value_counts()
# Out:
# Maruti Suzuki    2720
# Hyundai          1529
# Honda             802
# Toyota            777
# Mahindra          560
# Mercedes-Benz     402
# Tata              389
# BMW               342
# Volkswagen        318
# Audi              264
# Ford              245
# Renault           240
# Skoda             183
# Kia               161
# Chevrolet          89
# MG                 80
# Nissan             75
# Jeep               74
# Land Rover         71
# Volvo              48
# Mini               41
# Jaguar             34
# Porsche            24
# Fiat               22
# Datsun             22
# Lexus              20
# Mitsubishi         18
# Isuzu              10
# Force               6
# Ambassador          3
# Rolls-Royce         2
# Bajaj               2
# Opel                2
# Ssangyong           2
# Aston Martin        1
# ICML                1
# Ashok               1
# Bentley             1
# Maserati            1
# Name: Brand, dtype: int64

# %%
#group based on brand and model
car_data.groupby(['Brand', 'model']).model.count()
# Out:
# Brand         model
# Ambassador    Ambassador            3
# Ashok         Leyland Stile         1
# Aston Martin  Vanquish              1
# Audi          2.9 Sportback         1
#               A3                   41
#                                    ..
# Volvo         V40 Cross Country     1
#               XC 90                 6
#               XC40                  3
#               XC60                 12
#               XC90                  1
# Name: model, Length: 401, dtype: int64

# %%
car_data.groupby(['Brand', 'model']).price_in_rupiah.agg([len, min, max])
# Out:
#                                 len         min         max
# Brand        model
# Ambassador   Ambassador           3    28243800   188216494
# Ashok        Leyland Stile        1     6025344     6025344
# Aston Martin Vanquish             1 -2147483648 -2147483648
# Audi         2.9 Sportback        1  1412190000  1412190000
#              A3                  41   160048200   414242400
# ...                             ...         ...         ...
# Volvo        V40 Cross Country    1   258901500   258901500
#              XC 90                6   202413900  1299214800
#              XC40                 3   431188680   560168700
#              XC60                12   164755500  1186239600
#              XC90                 1   705906708   705906708
#
# [401 rows x 3 columns]

# %%
car_data.groupby(['PostedDate','Brand','model']).model.count()
# Out:
# PostedDate  Brand          model
# Apr-24      Hyundai        Santro       1
#                            Verna        2
#             Maruti Suzuki  Baleno       1
#                            Celerio      1
#             Volkswagen     Vento        1
#                                        ..
# Sep-24      Volkswagen     Passat       1
#                            Polo         2
#                            Vento        4
#                            VentoTest    1
#             Volvo          S90          1
# Name: model, Length: 734, dtype: int64
